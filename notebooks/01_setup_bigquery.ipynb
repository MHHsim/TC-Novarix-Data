# %%
import os
print(os.path.exists(os.getenv("GOOGLE_APPLICATION_CREDENTIALS")))
print(os.getenv("GOOGLE_APPLICATION_CREDENTIALS"))
# Out:
# False
# C:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\tc-novarix-data.json

# %%
from google.cloud import bigquery
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

project_id = os.getenv("GCP_PROJECT_ID")
dataset_id = os.getenv("BQ_DATASET_ID")

client = bigquery.Client(project=project_id)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[11], line 12
#       8
#       9 project_id = os.getenv("GCP_PROJECT_ID")
#      10 dataset_id = os.getenv("BQ_DATASET_ID")
#      11
# ---> 12 client = bigquery.Client(project=project_id)
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\cloud\bigquery\client.py:261, in Client.__init__(self, project, credentials, _http, location, default_query_job_config, default_load_job_config, client_info, client_options, default_job_creation_mode)
#     258     client_options = google.api_core.client_options.from_dict(client_options)
#     259 # assert isinstance(client_options, google.api_core.client_options.ClientOptions)
# --> 261 super(Client, self).__init__(
#     262     project=project,
#     263     credentials=credentials,
#     264     client_options=client_options,
#     265     _http=_http,
#     266 )
#     268 kw_args: Dict[str, Any] = {"client_info": client_info}
#     269 bq_host = _get_bigquery_host()
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\cloud\client\__init__.py:340, in ClientWithProject.__init__(self, project, credentials, client_options, _http)
#     338 def __init__(self, project=None, credentials=None, client_options=None, _http=None):
#     339     _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
# --> 340     Client.__init__(
#     341         self, credentials=credentials, client_options=client_options, _http=_http
#     342     )
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\cloud\client\__init__.py:197, in Client.__init__(self, credentials, _http, client_options)
#     195         credentials = google.auth.api_key.Credentials(client_options.api_key)
#     196     else:
# --> 197         credentials, _ = google.auth.default(scopes=scopes)
#     199 self._credentials = google.auth.credentials.with_scopes_if_required(
#     200     credentials, scopes=scopes
#     201 )
#     203 if client_options.quota_project_id:
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\auth\_default.py:714, in default(scopes, request, quota_project_id, default_scopes)
#     702 checkers = (
#     703     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     704     # with_scopes_if_required() below will ensure scopes/default scopes are
#    (...)    710     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     711 )
#     713 for checker in checkers:
# --> 714     credentials, project_id = checker()
#     715     if credentials is not None:
#     716         credentials = with_scopes_if_required(
#     717             credentials, scopes, default_scopes=default_scopes
#     718         )
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\auth\_default.py:707, in default.<locals>.<lambda>()
#     696 from google.auth.credentials import CredentialsWithQuotaProject
#     698 explicit_project_id = os.environ.get(
#     699     environment_vars.PROJECT, os.environ.get(environment_vars.LEGACY_PROJECT)
#     700 )
#     702 checkers = (
#     703     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     704     # with_scopes_if_required() below will ensure scopes/default scopes are
#     705     # safely set on the returned credentials since requires_scopes will
#     706     # guard against setting scopes on user credentials.
# --> 707     lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     708     lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     709     _get_gae_credentials,
#     710     lambda: _get_gce_credentials(request, quota_project_id=quota_project_id),
#     711 )
#     713 for checker in checkers:
#     714     credentials, project_id = checker()
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\auth\_default.py:352, in _get_explicit_environ_credentials(quota_project_id)
#     350 with warnings.catch_warnings():
#     351     warnings.simplefilter("ignore", DeprecationWarning)
# --> 352     credentials, project_id = load_credentials_from_file(
#     353         os.environ[environment_vars.CREDENTIALS],
#     354         quota_project_id=quota_project_id,
#     355     )
#     356     credentials._cred_file_path = f"{explicit_file} file via the GOOGLE_APPLICATION_CREDENTIALS environment variable"
#     357     return credentials, project_id
#
# File c:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\venv\Lib\site-packages\google\auth\_default.py:178, in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#     175 _warn_about_generic_load_method("load_credentials_from_file")
#     177 if not os.path.exists(filename):
# --> 178     raise exceptions.DefaultCredentialsError(
#     179         "File {} was not found.".format(filename)
#     180     )
#     182 with io.open(filename, "r") as file_obj:
#     183     try:
#
# DefaultCredentialsError: File C:\Users\Usuario\Documents\GitHub\Repositorio_persona\TC-Novarix-Data\tc-novarix-data.json was not found.

# %%
tables = client.list_tables("shopnow")
for t in tables:
    print(t.table_id)
# Out:
# categories
# customers
# order_item_id
# orders
# payments
# products
# reviews
